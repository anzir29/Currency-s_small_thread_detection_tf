# %% [markdown]
# # Counterfeit Currency detection
#
# Hoque, Khadija Kubra Shahjalal - 20-91624-1
# Chowdhury, Anjir Ahmed - 19-91478-3
# Nowshin, Nabila - 19-91417-3
#
# Group No : 1

# %% [markdown]
# # Dataset

# %%
from IPython.display import Image
Image(filename='collage.jpg')

# %% [markdown]
#  # Result

# %% [markdown]
# | Model Names | Speed | coco maP | K_Fold_1_aP | K_Fold_2_aP | K_Fold_3_aP | K_Fold_4_aP | Test_aP |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | ssd_mobilenet_v1_coco | 30 | 21 | 0.678 | 0.738 | 0.678 | 0.722 | 0.658 |
# | ssdlite_mobilenet_v2_coco | 27 | 22 | 0.712 | 0.725 | 0.767 | 0.767 | 0.703 |
# | Ssd_mobilenet_v2_coco | 31 | 22 | 0.793 | 0.763 | 0.755 | 0.764 | 0.729 |
# | ssd_inception_v2_coco | 42 | 24 | 0.812 | 0.810 | 0.800 | 0.796 | 0.743 |
# | Faster_rcnn_inception_v2_coco | 58 | 28 | 0.918 | 0.928 | 0.916 | 0.918 | 0.817 |
# | faster_rcnn_resnet50_coco | 89 | 90 | 0.920 | 0.928 | 0.916 | 0.920 | 0.854 |
# | rfcn_resnet101_coco| 92 | 30 | 0.914 | 0.914 | 0.910 | 0.911 | 0.846 |
# | faster_rcnn_inception_resnet_v2_atrous_coco| 620 | 37 | 0.921 | 0.916 | 0.898 | 0.921 | 0.880 |

# %% [markdown]
# # Model Link
#
# https://drive.google.com/file/d/18nj_SZlM2Hc1NOPIP1-43_55YgkDD2xj/view?usp=sharing

# %% [markdown]
# # Outputs

# %%
from IPython.display import Image
Image(filename='1.png')

# %%
from IPython.display import Image
Image(filename='4.png')
